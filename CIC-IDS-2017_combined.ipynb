# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
import numpy as np
from my_functions_for_ml import *

# %%
pd.set_option("display.max_columns",None)

# %%
import pandas as pd
import glob

# List all CSV files in the folder (adjust the path as needed)
# files = glob.glob("MachineLearningCVE/*.csv")

# List of CSVs to combine (customize as needed)
files = [
    "MachineLearningCVE/Friday-WorkingHours-Afternoon-DDos.pcap_ISCX.csv",
    "MachineLearningCVE/Friday-WorkingHours-Afternoon-PortScan.pcap_ISCX.csv",
    "MachineLearningCVE/Thursday-WorkingHours-Afternoon-Infilteration.pcap_ISCX.csv",
    "MachineLearningCVE/Thursday-WorkingHours-Morning-WebAttacks.pcap_ISCX.csv",
    "MachineLearningCVE/Wednesday-workingHours.pcap_ISCX.csv"
]

# Read and concatenate
df_list = [pd.read_csv(f) for f in files]
combined_df = pd.concat(df_list, ignore_index=True)  # preserves columns and stacks rows :contentReference[oaicite:2]{index=2}

print("Combined shape:", combined_df.shape)
# Out:
# Combined shape: (1663883, 79)

# %%
# Combine
# df = pd.concat([ddos, benign])
df = combined_df[:]

# %%
# Clean the column name first
df.columns = df.columns.str.strip()

# %%
print("Combine",df["Label"].value_counts())
# Out:
# Combine Label
# BENIGN                        1122038
# DoS Hulk                       231073
# PortScan                       158930
# DDoS                           128027
# DoS GoldenEye                   10293
# DoS slowloris                    5796
# DoS Slowhttptest                 5499
# Web Attack � Brute Force         1507
# Web Attack � XSS                  652
# Infiltration                       36
# Web Attack � Sql Injection         21
# Heartbleed                         11
# Name: count, dtype: int64

# %%
df.sample(10)
# Out:
#          Destination Port  Flow Duration  Total Fwd Packets  \
# 725288               5030             49                  2
# 1538394                53          94189                  2
# 1155105                80       98878989                  9
# 1430500                53          87060                  4
# 1243153                80       98676627                  8
# 642715              19780              4                  2
# 327335               8443             78                  1
# 805420                 53          48335                  1
# 103725              49621       80656407                  5
# 806622                 88            385                  2
#
#          Total Backward Packets  Total Length of Fwd Packets  \
# 725288                        0                            4
# 1538394                       2                           72
# 1155105                       7                          365
# 1430500                       4                          168
# 1243153                       6                          348
# 642715                        0                            4
# 327335                        1                            2
# 805420                        1                           40
# 103725                       10                        11613
# 806622                        2                          302
#
#          Total Length of Bwd Packets  Fwd Packet Length Max  \
# 725288                             0                      2
# 1538394                          286                     36
# 1155105                        11595                    365
# 1430500                          324                     42
# 1243153                        11595                    348
# 642715                             0                      2
# 327335                             6                      2
# 805420                           109                     40
# 103725                            68                  11595
# 806622                           404                    151
#
#          Fwd Packet Length Min  Fwd Packet Length Mean  Fwd Packet Length Std  \
# 725288                       2                2.000000               0.000000
# 1538394                     36               36.000000               0.000000
# 1155105                      0               40.555556             121.666667
# 1430500                     42               42.000000               0.000000
# 1243153                      0               43.500000             123.036580
# 642715                       2                2.000000               0.000000
# 327335                       2                2.000000               0.000000
# 805420                      40               40.000000               0.000000
# 103725                       0             2322.600000            5183.429830
# 806622                     151              151.000000               0.000000
#
#          Bwd Packet Length Max  Bwd Packet Length Min  Bwd Packet Length Mean  \
# 725288                       0                      0                0.000000
# 1538394                    143                    143              143.000000
# 1155105                   5792                      0             1656.428571
# 1430500                     81                     81               81.000000
# 1243153                   5792                      0             1932.500000
# 642715                       0                      0                0.000000
# 327335                       6                      6                6.000000
# 805420                     109                    109              109.000000
# 103725                      20                      0                6.800000
# 806622                     202                    202              202.000000
#
#          Bwd Packet Length Std  Flow Bytes/s  Flow Packets/s  Flow IAT Mean  \
# 725288                0.000000  8.163265e+04    40816.326530   4.900000e+01
# 1538394               0.000000  3.800868e+03       42.467804   3.139633e+04
# 1155105            2118.227235  1.209559e+02        0.161814   6.591933e+06
# 1430500               0.000000  5.651275e+03       91.890650   1.243714e+04
# 1243153            2537.820147  1.210317e+02        0.141878   7.590510e+06
# 642715                0.000000  1.000000e+06   500000.000000   4.000000e+00
# 327335                0.000000  1.025641e+05    25641.025640   7.800000e+01
# 805420                0.000000  3.082652e+03       41.377884   4.833500e+04
# 103725                5.006662  1.448242e+02        0.185974   5.761172e+06
# 806622                0.000000  1.833766e+06    10389.610390   1.283333e+02
#
#          Flow IAT Std  Flow IAT Max  Flow IAT Min  Fwd IAT Total  \
# 725288   0.000000e+00            49            49             49
# 1538394  5.433588e+04         94138             4              4
# 1155105  2.550000e+07      98700000             1       98700000
# 1430500  3.273946e+04         86683             3          86878
# 1243153  2.740000e+07      98700000             1       98700000
# 642715   0.000000e+00             4             4              4
# 327335   0.000000e+00            78            78              0
# 805420   0.000000e+00         48335         48335              0
# 103725   2.090000e+07      78200000             1       80700000
# 806622   2.153517e+02           377             4              4
#
#          Fwd IAT Mean   Fwd IAT Std  Fwd IAT Max  Fwd IAT Min  Bwd IAT Total  \
# 725288   4.900000e+01  0.000000e+00           49           49              0
# 1538394  4.000000e+00  0.000000e+00            4            4             47
# 1155105  1.230000e+07  3.490000e+07     98700000            1         151715
# 1430500  2.895933e+04  5.015384e+04        86872            3          86871
# 1243153  1.410000e+07  3.730000e+07     98700000            1           2908
# 642715   4.000000e+00  0.000000e+00            4            4              0
# 327335   0.000000e+00  0.000000e+00            0            0              0
# 805420   0.000000e+00  0.000000e+00            0            0              0
# 103725   2.020000e+07  4.010000e+07     80300000            6       80300000
# 806622   4.000000e+00  0.000000e+00            4            4              4
#
#          Bwd IAT Mean   Bwd IAT Std  Bwd IAT Max  Bwd IAT Min  Fwd PSH Flags  \
# 725288   0.000000e+00  0.000000e+00            0            0              0
# 1538394  4.700000e+01  0.000000e+00           47           47              0
# 1155105  2.528583e+04  5.511994e+04       137226           46              0
# 1430500  2.895700e+04  5.014980e+04        86865            3              0
# 1243153  5.816000e+02  1.061955e+03         2478           47              0
# 642715   0.000000e+00  0.000000e+00            0            0              0
# 327335   0.000000e+00  0.000000e+00            0            0              0
# 805420   0.000000e+00  0.000000e+00            0            0              0
# 103725   8.921671e+06  2.600000e+07     78200000            1              0
# 806622   4.000000e+00  0.000000e+00            4            4              0
#
#          Bwd PSH Flags  Fwd URG Flags  Bwd URG Flags  Fwd Header Length  \
# 725288               0              0              0                 48
# 1538394              0              0              0                 40
# 1155105              0              0              0                296
# 1430500              0              0              0                 80
# 1243153              0              0              0                264
# 642715               0              0              0                 48
# 327335               0              0              0                 24
# 805420               0              0              0                 20
# 103725               0              0              0                112
# 806622               0              0              0                 40
#
#          Bwd Header Length  Fwd Packets/s  Bwd Packets/s  Min Packet Length  \
# 725288                   0   40816.326530       0.000000                  2
# 1538394                 40      21.233902      21.233902                 36
# 1155105                232       0.091020       0.070794                  0
# 1430500                 80      45.945325      45.945325                 42
# 1243153                200       0.081073       0.060805                  0
# 642715                   0  500000.000000       0.000000                  2
# 327335                  20   12820.512820   12820.512820                  2
# 805420                  20      20.688942      20.688942                 40
# 103725                 212       0.061991       0.123983                  0
# 806622                  40    5194.805195    5194.805195                151
#
#          Max Packet Length  Packet Length Mean  Packet Length Std  \
# 725288                   2            2.000000           0.000000
# 1538394                143           78.800000          58.606314
# 1155105               5792          703.529412        1537.990211
# 1430500                 81           59.333333          20.554805
# 1243153               5792          796.200000        1797.261417
# 642715                   2            2.000000           0.000000
# 327335                   6            3.333333           2.309401
# 805420                 109           63.000000          39.837169
# 103725               11595          730.437500        2897.219747
# 806622                 202          171.400000          27.933850
#
#          Packet Length Variance  FIN Flag Count  SYN Flag Count  \
# 725288             0.000000e+00               0               0
# 1538394            3.434700e+03               0               0
# 1155105            2.365414e+06               0               0
# 1430500            4.225000e+02               0               0
# 1243153            3.230149e+06               0               0
# 642715             0.000000e+00               0               0
# 327335             5.333333e+00               0               0
# 805420             1.587000e+03               0               0
# 103725             8.393882e+06               0               0
# 806622             7.803000e+02               0               0
#
#          RST Flag Count  PSH Flag Count  ACK Flag Count  URG Flag Count  \
# 725288                0               1               0               0
# 1538394               0               0               0               0
# 1155105               0               0               1               0
# 1430500               0               0               0               0
# 1243153               0               0               1               0
# 642715                0               1               0               0
# 327335                0               1               0               0
# 805420                0               0               0               0
# 103725                0               0               1               1
# 806622                0               0               0               0
#
#          CWE Flag Count  ECE Flag Count  Down/Up Ratio  Average Packet Size  \
# 725288                0               0              0             3.000000
# 1538394               0               0              1            98.500000
# 1155105               0               0              0           747.500000
# 1430500               0               0              1            66.750000
# 1243153               0               0              0           853.071429
# 642715                0               0              0             3.000000
# 327335                0               0              1             5.000000
# 805420                0               0              1            94.500000
# 103725                0               0              2           779.133333
# 806622                0               0              1           214.250000
#
#          Avg Fwd Segment Size  Avg Bwd Segment Size  Fwd Header Length.1  \
# 725288               2.000000              0.000000                   48
# 1538394             36.000000            143.000000                   40
# 1155105             40.555556           1656.428571                  296
# 1430500             42.000000             81.000000                   80
# 1243153             43.500000           1932.500000                  264
# 642715               2.000000              0.000000                   48
# 327335               2.000000              6.000000                   24
# 805420              40.000000            109.000000                   20
# 103725            2322.600000              6.800000                  112
# 806622             151.000000            202.000000                   40
#
#          Fwd Avg Bytes/Bulk  Fwd Avg Packets/Bulk  Fwd Avg Bulk Rate  \
# 725288                    0                     0                  0
# 1538394                   0                     0                  0
# 1155105                   0                     0                  0
# 1430500                   0                     0                  0
# 1243153                   0                     0                  0
# 642715                    0                     0                  0
# 327335                    0                     0                  0
# 805420                    0                     0                  0
# 103725                    0                     0                  0
# 806622                    0                     0                  0
#
#          Bwd Avg Bytes/Bulk  Bwd Avg Packets/Bulk  Bwd Avg Bulk Rate  \
# 725288                    0                     0                  0
# 1538394                   0                     0                  0
# 1155105                   0                     0                  0
# 1430500                   0                     0                  0
# 1243153                   0                     0                  0
# 642715                    0                     0                  0
# 327335                    0                     0                  0
# 805420                    0                     0                  0
# 103725                    0                     0                  0
# 806622                    0                     0                  0
#
#          Subflow Fwd Packets  Subflow Fwd Bytes  Subflow Bwd Packets  \
# 725288                     2                  4                    0
# 1538394                    2                 72                    2
# 1155105                    9                365                    7
# 1430500                    4                168                    4
# 1243153                    8                348                    6
# 642715                     2                  4                    0
# 327335                     1                  2                    1
# 805420                     1                 40                    1
# 103725                     5              11613                   10
# 806622                     2                302                    2
#
#          Subflow Bwd Bytes  Init_Win_bytes_forward  Init_Win_bytes_backward  \
# 725288                   0                    1024                       -1
# 1538394                286                      -1                       -1
# 1155105              11595                     251                      235
# 1430500                324                      -1                       -1
# 1243153              11595                     251                      235
# 642715                   0                    1024                       -1
# 327335                   6                    1024                        0
# 805420                 109                      -1                       -1
# 103725                  68                     229                      256
# 806622                 404                      -1                       -1
#
#          act_data_pkt_fwd  min_seg_size_forward  Active Mean  Active Std  \
# 725288                  1                    24          0.0         0.0
# 1538394                 1                    20          0.0         0.0
# 1155105                 1                    32      13987.0         0.0
# 1430500                 3                    20          0.0         0.0
# 1243153                 1                    32       1987.0         0.0
# 642715                  1                    24          0.0         0.0
# 327335                  0                    24          0.0         0.0
# 805420                  0                    20          0.0         0.0
# 103725                  3                    20    2108517.0         0.0
# 806622                  1                    20          0.0         0.0
#
#          Active Max  Active Min   Idle Mean  Idle Std  Idle Max  Idle Min  \
# 725288            0           0         0.0       0.0         0         0
# 1538394           0           0         0.0       0.0         0         0
# 1155105       13987       13987  98700000.0       0.0  98700000  98700000
# 1430500           0           0         0.0       0.0         0         0
# 1243153        1987        1987  98700000.0       0.0  98700000  98700000
# 642715            0           0         0.0       0.0         0         0
# 327335            0           0         0.0       0.0         0         0
# 805420            0           0         0.0       0.0         0         0
# 103725      2108517     2108517  78200000.0       0.0  78200000  78200000
# 806622            0           0         0.0       0.0         0         0
#
#             Label
# 725288     BENIGN
# 1538394    BENIGN
# 1155105  DoS Hulk
# 1430500    BENIGN
# 1243153  DoS Hulk
# 642715     BENIGN
# 327335   PortScan
# 805420     BENIGN
# 103725     BENIGN
# 806622     BENIGN

# %%
# Get total number of rows
total = len(df)

# Get label counts and percentages
label_counts = df["Label"].value_counts()
label_percentages = (label_counts / total) * 100

# Display counts and percentages
print("Label Counts:\n", label_counts)
print("\nLabel Percentages (%):\n", label_percentages.round(2))
# Out:
# Label Counts:
#  Label
# BENIGN                        1122038
# DoS Hulk                       231073
# PortScan                       158930
# DDoS                           128027
# DoS GoldenEye                   10293
# DoS slowloris                    5796
# DoS Slowhttptest                 5499
# Web Attack � Brute Force         1507
# Web Attack � XSS                  652
# Infiltration                       36
# Web Attack � Sql Injection         21
# Heartbleed                         11
# Name: count, dtype: int64
#
# Label Percentages (%):
#  Label
# BENIGN                        67.43
# DoS Hulk                      13.89
# PortScan                       9.55
# DDoS                           7.69
# DoS GoldenEye                  0.62
# DoS slowloris                  0.35
# DoS Slowhttptest               0.33
# Web Attack � Brute Force       0.09
# Web Attack � XSS               0.04
# Infiltration                   0.00
# Web Attack � Sql Injection     0.00
# Heartbleed                     0.00
# Name: count, dtype: float64

# %%
columns = df.columns
columns
# Out:
# Index(['Destination Port', 'Flow Duration', 'Total Fwd Packets',
#        'Total Backward Packets', 'Total Length of Fwd Packets',
#        'Total Length of Bwd Packets', 'Fwd Packet Length Max',
#        'Fwd Packet Length Min', 'Fwd Packet Length Mean',
#        'Fwd Packet Length Std', 'Bwd Packet Length Max',
#        'Bwd Packet Length Min', 'Bwd Packet Length Mean',
#        'Bwd Packet Length Std', 'Flow Bytes/s', 'Flow Packets/s',
#        'Flow IAT Mean', 'Flow IAT Std', 'Flow IAT Max', 'Flow IAT Min',
#        'Fwd IAT Total', 'Fwd IAT Mean', 'Fwd IAT Std', 'Fwd IAT Max',
#        'Fwd IAT Min', 'Bwd IAT Total', 'Bwd IAT Mean', 'Bwd IAT Std',
#        'Bwd IAT Max', 'Bwd IAT Min', 'Fwd PSH Flags', 'Bwd PSH Flags',
#        'Fwd URG Flags', 'Bwd URG Flags', 'Fwd Header Length',
#        'Bwd Header Length', 'Fwd Packets/s', 'Bwd Packets/s',
#        'Min Packet Length', 'Max Packet Length', 'Packet Length Mean',
#        'Packet Length Std', 'Packet Length Variance', 'FIN Flag Count',
#        'SYN Flag Count', 'RST Flag Count', 'PSH Flag Count', 'ACK Flag Count',
#        'URG Flag Count', 'CWE Flag Count', 'ECE Flag Count', 'Down/Up Ratio',
#        'Average Packet Size', 'Avg Fwd Segment Size', 'Avg Bwd Segment Size',
#        'Fwd Header Length.1', 'Fwd Avg Bytes/Bulk', 'Fwd Avg Packets/Bulk',
#        'Fwd Avg Bulk Rate', 'Bwd Avg Bytes/Bulk', 'Bwd Avg Packets/Bulk',
#        'Bwd Avg Bulk Rate', 'Subflow Fwd Packets', 'Subflow Fwd Bytes',
#        'Subflow Bwd Packets', 'Subflow Bwd Bytes', 'Init_Win_bytes_forward',
#        'Init_Win_bytes_backward', 'act_data_pkt_fwd', 'min_seg_size_forward',
#        'Active Mean', 'Active Std', 'Active Max', 'Active Min', 'Idle Mean',
#        'Idle Std', 'Idle Max', 'Idle Min', 'Label'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1663883 entries, 0 to 1663882
# Data columns (total 79 columns):
#  #   Column                       Non-Null Count    Dtype
# ---  ------                       --------------    -----
#  0   Destination Port             1663883 non-null  int64
#  1   Flow Duration                1663883 non-null  int64
#  2   Total Fwd Packets            1663883 non-null  int64
#  3   Total Backward Packets       1663883 non-null  int64
#  4   Total Length of Fwd Packets  1663883 non-null  int64
#  5   Total Length of Bwd Packets  1663883 non-null  int64
#  6   Fwd Packet Length Max        1663883 non-null  int64
#  7   Fwd Packet Length Min        1663883 non-null  int64
#  8   Fwd Packet Length Mean       1663883 non-null  float64
#  9   Fwd Packet Length Std        1663883 non-null  float64
#  10  Bwd Packet Length Max        1663883 non-null  int64
#  11  Bwd Packet Length Min        1663883 non-null  int64
#  12  Bwd Packet Length Mean       1663883 non-null  float64
#  13  Bwd Packet Length Std        1663883 non-null  float64
#  14  Flow Bytes/s                 1662818 non-null  float64
#  15  Flow Packets/s               1663883 non-null  float64
#  16  Flow IAT Mean                1663883 non-null  float64
#  17  Flow IAT Std                 1663883 non-null  float64
#  18  Flow IAT Max                 1663883 non-null  int64
#  19  Flow IAT Min                 1663883 non-null  int64
#  20  Fwd IAT Total                1663883 non-null  int64
#  21  Fwd IAT Mean                 1663883 non-null  float64
#  22  Fwd IAT Std                  1663883 non-null  float64
#  23  Fwd IAT Max                  1663883 non-null  int64
#  24  Fwd IAT Min                  1663883 non-null  int64
#  25  Bwd IAT Total                1663883 non-null  int64
#  26  Bwd IAT Mean                 1663883 non-null  float64
#  27  Bwd IAT Std                  1663883 non-null  float64
#  28  Bwd IAT Max                  1663883 non-null  int64
#  29  Bwd IAT Min                  1663883 non-null  int64
#  30  Fwd PSH Flags                1663883 non-null  int64
#  31  Bwd PSH Flags                1663883 non-null  int64
#  32  Fwd URG Flags                1663883 non-null  int64
#  33  Bwd URG Flags                1663883 non-null  int64
#  34  Fwd Header Length            1663883 non-null  int64
#  35  Bwd Header Length            1663883 non-null  int64
#  36  Fwd Packets/s                1663883 non-null  float64
#  37  Bwd Packets/s                1663883 non-null  float64
#  38  Min Packet Length            1663883 non-null  int64
#  39  Max Packet Length            1663883 non-null  int64
#  40  Packet Length Mean           1663883 non-null  float64
#  41  Packet Length Std            1663883 non-null  float64
#  42  Packet Length Variance       1663883 non-null  float64
#  43  FIN Flag Count               1663883 non-null  int64
#  44  SYN Flag Count               1663883 non-null  int64
#  45  RST Flag Count               1663883 non-null  int64
#  46  PSH Flag Count               1663883 non-null  int64
#  47  ACK Flag Count               1663883 non-null  int64
#  48  URG Flag Count               1663883 non-null  int64
#  49  CWE Flag Count               1663883 non-null  int64
#  50  ECE Flag Count               1663883 non-null  int64
#  51  Down/Up Ratio                1663883 non-null  int64
#  52  Average Packet Size          1663883 non-null  float64
#  53  Avg Fwd Segment Size         1663883 non-null  float64
#  54  Avg Bwd Segment Size         1663883 non-null  float64
#  55  Fwd Header Length.1          1663883 non-null  int64
#  56  Fwd Avg Bytes/Bulk           1663883 non-null  int64
#  57  Fwd Avg Packets/Bulk         1663883 non-null  int64
#  58  Fwd Avg Bulk Rate            1663883 non-null  int64
#  59  Bwd Avg Bytes/Bulk           1663883 non-null  int64
#  60  Bwd Avg Packets/Bulk         1663883 non-null  int64
#  61  Bwd Avg Bulk Rate            1663883 non-null  int64
#  62  Subflow Fwd Packets          1663883 non-null  int64
#  63  Subflow Fwd Bytes            1663883 non-null  int64
#  64  Subflow Bwd Packets          1663883 non-null  int64
#  65  Subflow Bwd Bytes            1663883 non-null  int64
#  66  Init_Win_bytes_forward       1663883 non-null  int64
#  67  Init_Win_bytes_backward      1663883 non-null  int64
#  68  act_data_pkt_fwd             1663883 non-null  int64
#  69  min_seg_size_forward         1663883 non-null  int64
#  70  Active Mean                  1663883 non-null  float64
#  71  Active Std                   1663883 non-null  float64
#  72  Active Max                   1663883 non-null  int64
#  73  Active Min                   1663883 non-null  int64
#  74  Idle Mean                    1663883 non-null  float64
#  75  Idle Std                     1663883 non-null  float64
#  76  Idle Max                     1663883 non-null  int64
#  77  Idle Min                     1663883 non-null  int64
#  78  Label                        1663883 non-null  object
# dtypes: float64(24), int64(54), object(1)
# memory usage: 1002.9+ MB

# %%
#missing values
missing_percentage(df)
# Out:
# Flow Bytes/s  :  1065  : [ 72.94520547945206 %]

# %%
# Replace common missing values
missing_values = [-1, 'NaN', 'nan', '', ' ']
df.replace(missing_values, np.nan, inplace=True)
# Drop rows with missing or infinite values
df.replace([np.inf, -np.inf], 0, inplace=True)
df.replace(-1, 0, inplace=True)
# Replace -1 with NaN in these
df[['Init_Win_bytes_forward', 'Init_Win_bytes_backward']] = df[['Init_Win_bytes_forward', 'Init_Win_bytes_backward']].replace(-1, np.nan)
df.dropna(inplace=True)

# %%
def cat_value_count(df_new):
    import pandas as pd
    categorical_cols = df_new.columns  # Select categorical columns
    for col in categorical_cols:
        print(f"Value counts for column: {col}\n")
        print(df_new[col].value_counts(), "\n" + "-"*40 + "\n")  # Display counts for each unique value
    categorical_cols = df.columns  # Select categorical columns
    return categorical_cols

# %%
cat_value_count(df)
# Out:
# Value counts for column: Destination Port
#
# Destination Port
# 80       355026
# 443      185481
# 22         5730
# 21         2806
# 389        1960
#           ...
# 19066         1
# 19078         1
# 19063         1
# 19060         1
# 49032         1
# Name: count, Length: 43678, dtype: int64
# ----------------------------------------
#
# Value counts for column: Flow Duration
#
# Flow Duration
# 43.0           13568
# 44.0           12691
# 49.0           10988
# 48.0            8199
# 42.0            6622
#                ...
# 115760508.0        1
# 5168547.0          1
# 63785.0            1
# 104889.0           1
# 11512230.0         1
# Name: count, Length: 554053, dtype: int64
# ----------------------------------------
#
# Value counts for column: Total Fwd Packets
#
# Total Fwd Packets
# 1       288898
# 3       114643
# 8        65024
# 2        62256
# 7        60890
#          ...
# 5250         1
# 1387         1
# 710          1
# 821          1
# 1402         1
# Name: count, Length: 880, dtype: int64
# ----------------------------------------
#
# Value counts for column: Total Backward Packets
#
# Total Backward Packets
# 1      324780
# 6      126697
# 5       85487
# 7       63562
# 2       62557
#         ...
# 587         1
# 789         1
# 835         1
# 543         1
# 915         1
# Name: count, Length: 1110, dtype: int64
# ----------------------------------------
#
# Value counts for column: Total Length of Fwd Packets
#
# Total Length of Fwd Packets
# 0        155410
# 2         78955
# 6         69505
# 26        56772
# 4         31611
#           ...
# 13768         1
# 9711          1
# 7716          1
# 10278         1
# 10775         1
# Name: count, Length: 13019, dtype: int64
# ----------------------------------------
#
# Value counts for column: Total Length of Bwd Packets
#
# Total Length of Bwd Packets
# 6         230943
# 11595     154737
# 0          99788
# 11607      42868
# 11601      38463
#            ...
# 40454          1
# 47462          1
# 49755          1
# 58635          1
# 267793         1
# Name: count, Length: 40682, dtype: int64
# ----------------------------------------
#
# Value counts for column: Fwd Packet Length Max
#
# Fwd Packet Length Max
# 0       155410
# 2       110217
# 6       100923
# 20       81361
# 517      14981
#          ...
# 4484         1
# 5070         1
# 5394         1
# 4481         1
# 6046         1
# Name: count, Length: 4592, dtype: int64
# ----------------------------------------
#
# Value counts for column: Fwd Packet Length Min
#
# Fwd Packet Length Min
# 0       667936
# 2       110675
# 6       109625
# 1375      3218
# 8         1556
#          ...
# 51           1
# 883          1
# 924          1
# 20           1
# 7            1
# Name: count, Length: 147, dtype: int64
# ----------------------------------------
#
# Value counts for column: Fwd Packet Length Mean
#
# Fwd Packet Length Mean
# 0.000000      155410
# 2.000000      110821
# 6.000000       84565
# 8.666667       56620
# 7.000000       18076
#                ...
# 233.555556         1
# 37.935484          1
# 182.818182         1
# 51.677419          1
# 897.916667         1
# Name: count, Length: 53702, dtype: int64
# ----------------------------------------
#
# Value counts for column: Fwd Packet Length Std
#
# Fwd Packet Length Std
# 0.000000      356474
# 10.263203      56616
# 5.656854       18292
# 3.464102       14633
# 20.124612       7090
#                ...
# 445.448763         1
# 112.030757         1
# 84.891443          1
# 229.851764         1
# 300.527536         1
# Name: count, Length: 125712, dtype: int64
# ----------------------------------------
#
# Value counts for column: Bwd Packet Length Max
#
# Bwd Packet Length Max
# 6       292322
# 0        99788
# 5792     64841
# 4344     50738
# 1460     31794
#          ...
# 2893         1
# 4752         1
# 4599         1
# 4614         1
# 4572         1
# Name: count, Length: 4395, dtype: int64
# ----------------------------------------
#
# Value counts for column: Bwd Packet Length Min
#
# Bwd Packet Length Min
# 0      572618
# 6      292102
# 2       13965
# 46      12162
# 41       1063
#         ...
# 658         1
# 453         1
# 505         1
# 794         1
# 89          1
# Name: count, Length: 184, dtype: int64
# ----------------------------------------
#
# Value counts for column: Bwd Packet Length Mean
#
# Bwd Packet Length Mean
# 6.000000       283620
# 0.000000        99788
# 1932.500000     74938
# 1656.428571     44857
# 2319.000000     23014
#                 ...
# 1506.800000         1
# 408.952381          1
# 162.318182          1
# 199.288136          1
# 520.090909          1
# Name: count, Length: 78000, dtype: int64
# ----------------------------------------
#
# Value counts for column: Bwd Packet Length Std
#
# Bwd Packet Length Std
# 0.000000       402674
# 2181.008184     22099
# 1754.831473     18597
# 2120.732252      9205
# 5795.500690      8402
#                 ...
# 668.584681          1
# 787.085800          1
# 849.071066          1
# 1026.046967         1
# 330.994461          1
# Name: count, Length: 116397, dtype: int64
# ----------------------------------------
#
# Value counts for column: Flow Bytes/s
#
# Flow Bytes/s
# 0.000000         70706
# 186046.511600     6886
# 181818.181800     6817
# 136363.636400     6329
# 139534.883700     6270
#                  ...
# 623.498059           1
# 7518.708827          1
# 509.721623           1
# 56.552691            1
# 364.568811           1
# Name: count, Length: 568803, dtype: int64
# ----------------------------------------
#
# Value counts for column: Flow Packets/s
#
# Flow Packets/s
# 46511.627910    13607
# 45454.545450    12876
# 40816.326530     9909
# 41666.666670     6965
# 47619.047620     6927
#                 ...
# 23.303831           1
# 22.307238           1
# 159.864435          1
# 35.050824           1
# 0.868641            1
# Name: count, Length: 576598, dtype: int64
# ----------------------------------------
#
# Value counts for column: Flow IAT Mean
#
# Flow IAT Mean
# 4.300000e+01    13542
# 4.400000e+01    12615
# 4.900000e+01     8925
# 4.200000e+01     6585
# 4.800000e+01     6511
#                 ...
# 2.319542e+06        1
# 1.551677e+06        1
# 5.342965e+04        1
# 2.253859e+05        1
# 1.279137e+06        1
# Name: count, Length: 567370, dtype: int64
# ----------------------------------------
#
# Value counts for column: Flow IAT Std
#
# Flow IAT Std
# 0.000000e+00    258770
# 2.840000e+07      5547
# 2.850000e+07      5158
# 2.970000e+07      4382
# 2.450000e+07      4117
#                  ...
# 4.636607e+06         1
# 4.551450e+06         1
# 4.823998e+06         1
# 4.841603e+06         1
# 2.565060e+06         1
# Name: count, Length: 386510, dtype: int64
# ----------------------------------------
#
# Value counts for column: Flow IAT Max
#
# Flow IAT Max
# 10000000.0    59907
# 49.0          19387
# 48.0          15403
# 43.0          13673
# 10200000.0    13393
#               ...
# 405682.0          1
# 123392.0          1
# 122896.0          1
# 123112.0          1
# 6506213.0         1
# Name: count, Length: 246118, dtype: int64
# ----------------------------------------
#
# Value counts for column: Flow IAT Min
#
# Flow IAT Min
# 1.0         168284
# 3.0          96014
# 4.0          59851
# 2.0          47348
# 0.0          38179
#              ...
# 208440.0         1
# 211619.0         1
# 211271.0         1
# 30212.0          1
# 207406.0         1
# Name: count, Length: 18208, dtype: int64
# ----------------------------------------
#
# Value counts for column: Fwd IAT Total
#
# Fwd IAT Total
# 0            289309
# 116000000     23430
# 117000000     10596
# 118000000     10426
# 48            10028
#               ...
# 64600             1
# 71426             1
# 4769293           1
# 64527             1
# 6509115           1
# Name: count, Length: 178072, dtype: int64
# ----------------------------------------
#
# Value counts for column: Fwd IAT Mean
#
# Fwd IAT Mean
# 0.000000e+00    289309
# 4.800000e+01      9973
# 4.900000e+01      9499
# 1.970000e+07      8149
# 1.410000e+07      8127
#                  ...
# 5.267509e+06         1
# 4.830181e+06         1
# 6.413569e+06         1
# 7.687523e+06         1
# 1.627279e+06         1
# Name: count, Length: 308515, dtype: int64
# ----------------------------------------
#
# Value counts for column: Fwd IAT Std
#
# Fwd IAT Std
# 0.000000e+00    351419
# 4.400000e+07      3815
# 4.410000e+07      3634
# 3.480000e+07      3276
# 3.720000e+07      3225
#                  ...
# 3.766092e+06         1
# 1.839470e+04         1
# 1.834609e+04         1
# 2.341867e+04         1
# 3.253892e+06         1
# Name: count, Length: 280965, dtype: int64
# ----------------------------------------
#
# Value counts for column: Fwd IAT Max
#
# Fwd IAT Max
# 0           289309
# 10000000     36945
# 10100000     27465
# 10200000     15377
# 48           10183
#              ...
# 137429           1
# 200163           1
# 4183360          1
# 5183714          1
# 6508117          1
# Name: count, Length: 173393, dtype: int64
# ----------------------------------------
#
# Value counts for column: Fwd IAT Min
#
# Fwd IAT Min
# 0.0         309322
# 1.0         111662
# 3.0          67439
# 4.0          42436
# 48.0         25836
#              ...
# 499890.0         1
# 34989.0          1
# 22554.0          1
# 50460.0          1
# 8336.0           1
# Name: count, Length: 41353, dtype: int64
# ----------------------------------------
#
# Value counts for column: Bwd IAT Total
#
# Bwd IAT Total
# 0            325304
# 111000000     17584
# 48            10607
# 49            10044
# 1              9307
#               ...
# 1074888           1
# 1073642           1
# 1062863           1
# 1028533           1
# 804042            1
# Name: count, Length: 237669, dtype: int64
# ----------------------------------------
#
# Value counts for column: Bwd IAT Mean
#
# Bwd IAT Mean
# 0.000          325304
# 48.000          10559
# 49.000           9760
# 1.000            9668
# 3.000            5802
#                 ...
# 512264.000          1
# 7820435.467         1
# 501288.500          1
# 501160.000          1
# 2878045.500         1
# Name: count, Length: 391647, dtype: int64
# ----------------------------------------
#
# Value counts for column: Bwd IAT Std
#
# Bwd IAT Std
# 0.000000e+00    387765
# 4.030000e+07      2432
# 4.020000e+07      1990
# 4.010000e+07      1877
# 4.060000e+07      1659
#                  ...
# 4.323778e+06         1
# 5.402421e+06         1
# 4.807465e+06         1
# 8.449290e+05         1
# 3.378842e+06         1
# Name: count, Length: 427062, dtype: int64
# ----------------------------------------
#
# Value counts for column: Bwd IAT Max
#
# Bwd IAT Max
# 0           325304
# 10000000     37862
# 10100000     31873
# 10200000     15479
# 48           10949
#              ...
# 3140958          1
# 6009345          1
# 3140233          1
# 3140423          1
# 6506213          1
# Name: count, Length: 224620, dtype: int64
# ----------------------------------------
#
# Value counts for column: Bwd IAT Min
#
# Bwd IAT Min
# 0          330648
# 1           64651
# 3           53407
# 48          45639
# 4           35499
#             ...
# 760991          1
# 777259          1
# 766363          1
# 787541          1
# 3268625         1
# Name: count, Length: 26635, dtype: int64
# ----------------------------------------
#
# Value counts for column: Fwd PSH Flags
#
# Fwd PSH Flags
# 0    856817
# 1     38010
# Name: count, dtype: int64
# ----------------------------------------
#
# Value counts for column: Bwd PSH Flags
#
# Bwd PSH Flags
# 0    894827
# Name: count, dtype: int64
# ----------------------------------------
#
# Value counts for column: Fwd URG Flags
#
# Fwd URG Flags
# 0    894819
# 1         8
# Name: count, dtype: int64
# ----------------------------------------
#
# Value counts for column: Bwd URG Flags
#
# Bwd URG Flags
# 0    894827
# Name: count, dtype: int64
# ----------------------------------------
#
# Value counts for column: Fwd Header Length
#
# Fwd Header Length
# 40       96220
# 24       78926
# 72       74852
# 20       71816
# 32       58033
#          ...
# 13716        1
# 3868         1
# 1968         1
# 45576        1
# 2716         1
# Name: count, Length: 2395, dtype: int64
# ----------------------------------------
#
# Value counts for column: Bwd Header Length
#
# Bwd Header Length
# 20       235684
# 200       82491
# 32        76710
# 40        53852
# 232       51424
#           ...
# 10752         1
# 13000         1
# 13112         1
# 96292         1
# 4476          1
# Name: count, Length: 2569, dtype: int64
# ----------------------------------------
#
# Value counts for column: Fwd Packets/s
#
# Fwd Packets/s
# 23255.813950    13664
# 22727.272730    12752
# 20408.163270    10225
# 20833.333330     7021
# 23809.523810     6800
#                 ...
# 0.153151            1
# 0.155854            1
# 8.695021            1
# 0.184874            1
# 0.434321            1
# Name: count, Length: 569647, dtype: int64
# ----------------------------------------
#
# Value counts for column: Bwd Packets/s
#
# Bwd Packets/s
# 23255.813950    13725
# 22727.272730    12809
# 20408.163270    10093
# 20833.333330     7026
# 23809.523810     6889
#                 ...
# 0.401906            1
# 0.164148            1
# 63.211125           1
# 70.727610           1
# 0.434321            1
# Name: count, Length: 567511, dtype: int64
# ----------------------------------------
#
# Value counts for column: Min Packet Length
#
# Min Packet Length
# 0     685977
# 2     112817
# 6      96027
# 31         3
# 5          1
# 20         1
# 37         1
# Name: count, dtype: int64
# ----------------------------------------
#
# Value counts for column: Max Packet Length
#
# Max Packet Length
# 6        291500
# 0         70138
# 5792      66557
# 4344      51978
# 1460      30396
#           ...
# 4492          1
# 12672         1
# 4906          1
# 4620          1
# 6046          1
# Name: count, Length: 5132, dtype: int64
# ----------------------------------------
#
# Value counts for column: Packet Length Mean
#
# Packet Length Mean
# 2.000000      80532
# 3.333333      78974
# 0.000000      70138
# 6.000000      69289
# 3.600000      34398
#               ...
# 359.684211        1
# 366.733333        1
# 215.592593        1
# 543.534884        1
# 939.692308        1
# Name: count, Length: 113423, dtype: int64
# ----------------------------------------
#
# Value counts for column: Packet Length Std
#
# Packet Length Std
# 0.000000       139463
# 3.464102        80826
# 2.309401        79374
# 2.190890        33156
# 3.286335        17103
#                 ...
# 1166.191104         1
# 1181.591313         1
# 1187.146990         1
# 741.438491          1
# 1857.187221         1
# Name: count, Length: 210910, dtype: int64
# ----------------------------------------
#
# Value counts for column: Packet Length Variance
#
# Packet Length Variance
# 0.000000e+00    139463
# 1.200000e+01     80826
# 5.333333e+00     79374
# 4.800000e+00     33156
# 1.080000e+01     17103
#                  ...
# 3.309761e+05         1
# 3.448899e+05         1
# 4.230697e+05         1
# 4.034360e+05         1
# 3.449144e+06         1
# Name: count, Length: 209022, dtype: int64
# ----------------------------------------
#
# Value counts for column: FIN Flag Count
#
# FIN Flag Count
# 0    828055
# 1     66772
# Name: count, dtype: int64
# ----------------------------------------
#
# Value counts for column: SYN Flag Count
#
# SYN Flag Count
# 0    856817
# 1     38010
# Name: count, dtype: int64
# ----------------------------------------
#
# Value counts for column: RST Flag Count
#
# RST Flag Count
# 0    894413
# 1       414
# Name: count, dtype: int64
# ----------------------------------------
#
# Value counts for column: PSH Flag Count
#
# PSH Flag Count
# 1    522620
# 0    372207
# Name: count, dtype: int64
# ----------------------------------------
#
# Value counts for column: ACK Flag Count
#
# ACK Flag Count
# 0    583462
# 1    311365
# Name: count, dtype: int64
# ----------------------------------------
#
# Value counts for column: URG Flag Count
#
# URG Flag Count
# 0    764426
# 1    130401
# Name: count, dtype: int64
# ----------------------------------------
#
# Value counts for column: CWE Flag Count
#
# CWE Flag Count
# 0    894819
# 1         8
# Name: count, dtype: int64
# ----------------------------------------
#
# Value counts for column: ECE Flag Count
#
# ECE Flag Count
# 0    894412
# 1       415
# Name: count, dtype: int64
# ----------------------------------------
#
# Value counts for column: Down/Up Ratio
#
# Down/Up Ratio
# 1      517174
# 0      315465
# 2       40098
# 5       10268
# 6        6439
# 3        3143
# 4        1520
# 7         677
# 29          8
# 8           8
# 10          4
# 27          4
# 9           3
# 39          2
# 43          2
# 156         1
# 26          1
# 21          1
# 74          1
# 20          1
# 32          1
# 25          1
# 90          1
# 11          1
# 124         1
# 16          1
# 12          1
# Name: count, dtype: int64
# ----------------------------------------
#
# Value counts for column: Average Packet Size
#
# Average Packet Size
# 3.000000       95161
# 5.000000       78941
# 0.000000       70138
# 9.000000       45961
# 4.500000       34344
#                ...
# 263.966102         1
# 329.380952         1
# 188.565217         1
# 147.705882         1
# 1018.000000        1
# Name: count, Length: 112111, dtype: int64
# ----------------------------------------
#
# Value counts for column: Avg Fwd Segment Size
#
# Avg Fwd Segment Size
# 0.000000      155410
# 2.000000      110821
# 6.000000       84565
# 8.666667       56620
# 7.000000       18076
#                ...
# 233.555556         1
# 37.935484          1
# 182.818182         1
# 51.677419          1
# 897.916667         1
# Name: count, Length: 53702, dtype: int64
# ----------------------------------------
#
# Value counts for column: Avg Bwd Segment Size
#
# Avg Bwd Segment Size
# 6.000000       283620
# 0.000000        99788
# 1932.500000     74938
# 1656.428571     44857
# 2319.000000     23014
#                 ...
# 1506.800000         1
# 408.952381          1
# 162.318182          1
# 199.288136          1
# 520.090909          1
# Name: count, Length: 78000, dtype: int64
# ----------------------------------------
#
# Value counts for column: Fwd Header Length.1
#
# Fwd Header Length.1
# 40       96220
# 24       78926
# 72       74852
# 20       71816
# 32       58033
#          ...
# 13716        1
# 3868         1
# 1968         1
# 45576        1
# 2716         1
# Name: count, Length: 2395, dtype: int64
# ----------------------------------------
#
# Value counts for column: Fwd Avg Bytes/Bulk
#
# Fwd Avg Bytes/Bulk
# 0    894827
# Name: count, dtype: int64
# ----------------------------------------
#
# Value counts for column: Fwd Avg Packets/Bulk
#
# Fwd Avg Packets/Bulk
# 0    894827
# Name: count, dtype: int64
# ----------------------------------------
#
# Value counts for column: Fwd Avg Bulk Rate
#
# Fwd Avg Bulk Rate
# 0    894827
# Name: count, dtype: int64
# ----------------------------------------
#
# Value counts for column: Bwd Avg Bytes/Bulk
#
# Bwd Avg Bytes/Bulk
# 0    894827
# Name: count, dtype: int64
# ----------------------------------------
#
# Value counts for column: Bwd Avg Packets/Bulk
#
# Bwd Avg Packets/Bulk
# 0    894827
# Name: count, dtype: int64
# ----------------------------------------
#
# Value counts for column: Bwd Avg Bulk Rate
#
# Bwd Avg Bulk Rate
# 0    894827
# Name: count, dtype: int64
# ----------------------------------------
#
# Value counts for column: Subflow Fwd Packets
#
# Subflow Fwd Packets
# 1       288898
# 3       114643
# 8        65024
# 2        62256
# 7        60890
#          ...
# 5250         1
# 1387         1
# 710          1
# 821          1
# 1402         1
# Name: count, Length: 880, dtype: int64
# ----------------------------------------
#
# Value counts for column: Subflow Fwd Bytes
#
# Subflow Fwd Bytes
# 0        155410
# 2         78955
# 6         69505
# 26        56772
# 4         31611
#           ...
# 13768         1
# 9711          1
# 7716          1
# 10278         1
# 10775         1
# Name: count, Length: 13019, dtype: int64
# ----------------------------------------
#
# Value counts for column: Subflow Bwd Packets
#
# Subflow Bwd Packets
# 1      324780
# 6      126697
# 5       85487
# 7       63562
# 2       62557
#         ...
# 587         1
# 789         1
# 835         1
# 543         1
# 915         1
# Name: count, Length: 1110, dtype: int64
# ----------------------------------------
#
# Value counts for column: Subflow Bwd Bytes
#
# Subflow Bwd Bytes
# 6         230943
# 11595     154737
# 0          99788
# 11607      42868
# 11601      38463
#            ...
# 37732          1
# 38042          1
# 125310         1
# 15088          1
# 267793         1
# Name: count, Length: 40687, dtype: int64
# ----------------------------------------
#
# Value counts for column: Init_Win_bytes_forward
#
# Init_Win_bytes_forward
# 29200.0    210279
# 8192.0     189384
# 1024.0     111068
# 0.0         66673
# 251.0       52448
#             ...
# 8302.0          1
# 1715.0          1
# 8035.0          1
# 6747.0          1
# 16318.0         1
# Name: count, Length: 5734, dtype: int64
# ----------------------------------------
#
# Value counts for column: Init_Win_bytes_backward
#
# Init_Win_bytes_backward
# 0.0        237574
# 235.0      176224
# 229.0       96408
# 256.0       27564
# 60.0         9971
#             ...
# 11697.0         1
# 17767.0         1
# 12593.0         1
# 27004.0         1
# 62785.0         1
# Name: count, Length: 9546, dtype: int64
# ----------------------------------------
#
# Value counts for column: act_data_pkt_fwd
#
# act_data_pkt_fwd
# 0       312728
# 1       152108
# 2       140282
# 3        61646
# 4        43862
#          ...
# 480          1
# 1006         1
# 766          1
# 455          1
# 1401         1
# Name: count, Length: 712, dtype: int64
# ----------------------------------------
#
# Value counts for column: min_seg_size_forward
#
# min_seg_size_forward
# 20.0    427730
# 32.0    274714
# 24.0    110217
# 40.0     80600
# 28.0      1400
# 44.0        88
# 36.0        77
# 31.0         1
# Name: count, dtype: int64
# ----------------------------------------
#
# Value counts for column: Active Mean
#
# Active Mean
# 0.0000         558693
# 5.0000           6388
# 4.0000           5893
# 6.0000           3104
# 2.0000           2696
#                 ...
# 169069.0000         1
# 36440.2500          1
# 138030.3333         1
# 41336.7000          1
# 379019.0000         1
# Name: count, Length: 174058, dtype: int64
# ----------------------------------------
#
# Value counts for column: Active Std
#
# Active Std
# 0.000000         792057
# 4.242641             12
# 0.707107             12
# 2.121320             11
# 4.949747             11
#                   ...
# 162785.232500         1
# 185013.042900         1
# 528577.610600         1
# 276614.192000         1
# 39823.095060          1
# Name: count, Length: 101868, dtype: int64
# ----------------------------------------
#
# Value counts for column: Active Max
#
# Active Max
# 0         558693
# 5           6388
# 4           5893
# 6           3104
# 2           2696
#            ...
# 38840          1
# 36689          1
# 362734         1
# 808655         1
# 119807         1
# Name: count, Length: 166837, dtype: int64
# ----------------------------------------
#
# Value counts for column: Active Min
#
# Active Min
# 0          558693
# 5            6405
# 4            6031
# 6            3105
# 2            2727
#             ...
# 114264          1
# 637992          1
# 1167567         1
# 414793          1
# 379019          1
# Name: count, Length: 106136, dtype: int64
# ----------------------------------------
#
# Value counts for column: Idle Mean
#
# Idle Mean
# 0.000000e+00    553731
# 1.000000e+07     29406
# 1.020000e+07      8481
# 1.000000e+08      8461
# 9.830000e+07      7214
#                  ...
# 9.585097e+06         1
# 9.584286e+06         1
# 9.991312e+06         1
# 9.993346e+06         1
# 6.506213e+06         1
# Name: count, Length: 87617, dtype: int64
# ----------------------------------------
#
# Value counts for column: Idle Std
#
# Idle Std
# 0.000000e+00    772145
# 1.880000e+07      1714
# 5.940000e+07       346
# 5.960000e+07       344
# 5.930000e+07       332
#                  ...
# 3.335211e+06         1
# 3.308695e+05         1
# 3.496629e+05         1
# 4.407743e+05         1
# 2.071331e+04         1
# Name: count, Length: 98185, dtype: int64
# ----------------------------------------
#
# Value counts for column: Idle Max
#
# Idle Max
# 0            553731
# 10000000      59694
# 10200000      13389
# 100000000      9549
# 98300000       7218
#               ...
# 5231520           1
# 5808468           1
# 5852361           1
# 5840582           1
# 6506213           1
# Name: count, Length: 48853, dtype: int64
# ----------------------------------------
#
# Value counts for column: Idle Min
#
# Idle Min
# 0            553731
# 10000000      14236
# 100000000      8461
# 98300000       7214
# 98700000       6242
#               ...
# 9957636           1
# 5141374           1
# 9939330           1
# 5238528           1
# 6506213           1
# Name: count, Length: 103422, dtype: int64
# ----------------------------------------
#
# Value counts for column: Label
#
# Label
# BENIGN                        474220
# DoS Hulk                      163867
# PortScan                      158866
# DDoS                           81481
# DoS GoldenEye                   7710
# DoS slowloris                   4154
# DoS Slowhttptest                2327
# Web Attack � Brute Force        1507
# Web Attack � XSS                 635
# Infiltration                      32
# Web Attack � Sql Injection        21
# Heartbleed                         7
# Name: count, dtype: int64
# ----------------------------------------
# Index(['Destination Port', 'Flow Duration', 'Total Fwd Packets',
#        'Total Backward Packets', 'Total Length of Fwd Packets',
#        'Total Length of Bwd Packets', 'Fwd Packet Length Max',
#        'Fwd Packet Length Min', 'Fwd Packet Length Mean',
#        'Fwd Packet Length Std', 'Bwd Packet Length Max',
#        'Bwd Packet Length Min', 'Bwd Packet Length Mean',
#        'Bwd Packet Length Std', 'Flow Bytes/s', 'Flow Packets/s',
#        'Flow IAT Mean', 'Flow IAT Std', 'Flow IAT Max', 'Flow IAT Min',
#        'Fwd IAT Total', 'Fwd IAT Mean', 'Fwd IAT Std', 'Fwd IAT Max',
#        'Fwd IAT Min', 'Bwd IAT Total', 'Bwd IAT Mean', 'Bwd IAT Std',
#        'Bwd IAT Max', 'Bwd IAT Min', 'Fwd PSH Flags', 'Bwd PSH Flags',
#        'Fwd URG Flags', 'Bwd URG Flags', 'Fwd Header Length',
#        'Bwd Header Length', 'Fwd Packets/s', 'Bwd Packets/s',
#        'Min Packet Length', 'Max Packet Length', 'Packet Length Mean',
#        'Packet Length Std', 'Packet Length Variance', 'FIN Flag Count',
#        'SYN Flag Count', 'RST Flag Count', 'PSH Flag Count', 'ACK Flag Count',
#        'URG Flag Count', 'CWE Flag Count', 'ECE Flag Count', 'Down/Up Ratio',
#        'Average Packet Size', 'Avg Fwd Segment Size', 'Avg Bwd Segment Size',
#        'Fwd Header Length.1', 'Fwd Avg Bytes/Bulk', 'Fwd Avg Packets/Bulk',
#        'Fwd Avg Bulk Rate', 'Bwd Avg Bytes/Bulk', 'Bwd Avg Packets/Bulk',
#        'Bwd Avg Bulk Rate', 'Subflow Fwd Packets', 'Subflow Fwd Bytes',
#        'Subflow Bwd Packets', 'Subflow Bwd Bytes', 'Init_Win_bytes_forward',
#        'Init_Win_bytes_backward', 'act_data_pkt_fwd', 'min_seg_size_forward',
#        'Active Mean', 'Active Std', 'Active Max', 'Active Min', 'Idle Mean',
#        'Idle Std', 'Idle Max', 'Idle Min', 'Label'],
#       dtype='object')

# %%
#Remove columns contain same/0 value for all rows
columns_to_drop = [
    'Fwd Avg Bytes/Bulk', 'Fwd Avg Packets/Bulk', 'Fwd Avg Bulk Rate',
    'Bwd Avg Bytes/Bulk', 'Bwd Avg Packets/Bulk', 'Bwd Avg Bulk Rate',
    'CWE Flag Count', 'Bwd URG Flags', 'Fwd URG Flags', 'Bwd PSH Flags',
    'Fwd Header Length.1'
]

# %%
df.drop(columns=columns_to_drop, inplace=True)

# %%
# Reset index
df.reset_index(drop=True, inplace=True)

# %%
df.shape
# Out:
# (894827, 68)

# %%
# Get total number of rows
total = len(df)

# Get label counts and percentages
label_counts = df["Label"].value_counts()
label_percentages = (label_counts / total) * 100

# Display counts and percentages
print("Label Counts:\n", label_counts)
print("\nLabel Percentages (%):\n", label_percentages.round(5))
# Out:
# Label Counts:
#  Label
# BENIGN                        474220
# DoS Hulk                      163867
# PortScan                      158866
# DDoS                           81481
# DoS GoldenEye                   7710
# DoS slowloris                   4154
# DoS Slowhttptest                2327
# Web Attack � Brute Force        1507
# Web Attack � XSS                 635
# Infiltration                      32
# Web Attack � Sql Injection        21
# Heartbleed                         7
# Name: count, dtype: int64
#
# Label Percentages (%):
#  Label
# BENIGN                        52.99572
# DoS Hulk                      18.31270
# PortScan                      17.75382
# DDoS                           9.10578
# DoS GoldenEye                  0.86162
# DoS slowloris                  0.46422
# DoS Slowhttptest               0.26005
# Web Attack � Brute Force       0.16841
# Web Attack � XSS               0.07096
# Infiltration                   0.00358
# Web Attack � Sql Injection     0.00235
# Heartbleed                     0.00078
# Name: count, dtype: float64

# %%
# Define mapping
group_map = {
    "DoS Hulk": "DoS/DDoS",
    "DDoS": "DoS/DDoS",
    "DoS GoldenEye": "DoS/DDoS",
    "DoS slowloris": "DoS/DDoS",
    "DoS Slowhttptest": "DoS/DDoS",
    "PortScan": "PortScan",
    "Web Attack – Brute Force": "Web Attack",
    "Web Attack � Brute Force": "Web Attack",
    "Web Attack – XSS": "Web Attack",
    "Web Attack � XSS": "Web Attack",
    "Web Attack – Sql Injection": "Web Attack",
    "Web Attack � Sql Injection": "Web Attack",
    "FTP-Patator": "Brute Force",
    "SSH-Patator": "Brute Force",
    "Bot": "Botnet",
    "Infiltration": "Other",
    "Heartbleed": "Other",
    # "Infiltration": "Infiltration",
    "BENIGN": "BENIGN"
}

df["Label_grouped"] = df["Label"].map(group_map)
print(df["Label_grouped"].value_counts())
# Out:
# Label_grouped
# BENIGN        474220
# DoS/DDoS      259539
# PortScan      158866
# Web Attack      2163
# Other             39
# Name: count, dtype: int64

# %%
df.drop(columns="Label", inplace=True)
df.reset_index(drop=True, inplace=True)

# %%
# Then drop missing
df = df.dropna(subset=['Label_grouped'])

# %%
df.sample(10)
# Out:
#         Destination Port  Flow Duration  Total Fwd Packets  \
# 238551              2035           17.0                  1
# 688424                80     98338747.0                  7
# 227367             19350           44.0                  1
# 439735              1114           71.0                  2
# 230560              4899           20.0                  1
# 215897             50300           21.0                  1
# 826781               443    118427692.0                 64
# 482204             51368           51.0                  3
# 332835               443       888296.0                 13
# 801054                80      5125758.0                  3
#
#         Total Backward Packets  Total Length of Fwd Packets  \
# 238551                       1                            0
# 688424                       6                          358
# 227367                       1                            2
# 439735                       2                            4
# 230560                       1                            2
# 215897                       1                            2
# 826781                      74                         1606
# 482204                       1                           43
# 332835                       8                          531
# 801054                       1                           12
#
#         Total Length of Bwd Packets  Fwd Packet Length Max  \
# 238551                            6                      0
# 688424                        11595                    352
# 227367                            6                      2
# 439735                           12                      2
# 230560                            6                      2
# 215897                            6                      2
# 826781                       112017                    416
# 482204                            6                     31
# 332835                         4922                    194
# 801054                            0                      6
#
#         Fwd Packet Length Min  Fwd Packet Length Mean  Fwd Packet Length Std  \
# 238551                      0                0.000000               0.000000
# 688424                      0               51.142857             132.684373
# 227367                      2                2.000000               0.000000
# 439735                      2                2.000000               0.000000
# 230560                      2                2.000000               0.000000
# 215897                      2                2.000000               0.000000
# 826781                      0               25.093750              90.861262
# 482204                      6               14.333333              14.433757
# 332835                      0               40.846154              73.701929
# 801054                      0                4.000000               3.464102
#
#         Bwd Packet Length Max  Bwd Packet Length Min  Bwd Packet Length Mean  \
# 238551                      6                      6                6.000000
# 688424                   5792                      0             1932.500000
# 227367                      6                      6                6.000000
# 439735                      6                      6                6.000000
# 230560                      6                      6                6.000000
# 215897                      6                      6                6.000000
# 826781                   4344                      0             1513.743243
# 482204                      6                      6                6.000000
# 332835                   1448                      0              615.250000
# 801054                      0                      0                0.000000
#
#         Bwd Packet Length Std   Flow Bytes/s  Flow Packets/s  Flow IAT Mean  \
# 238551               0.000000  352941.176500   117647.058800   1.700000e+01
# 688424            2181.008184     121.549240        0.132196   8.194896e+06
# 227367               0.000000  181818.181800    45454.545450   4.400000e+01
# 439735               0.000000  225352.112700    56338.028170   2.366667e+01
# 230560               0.000000  400000.000000   100000.000000   2.000000e+01
# 215897               0.000000  380952.381000    95238.095240   2.100000e+01
# 826781             988.812891     959.429320        1.165268   8.644357e+05
# 482204               0.000000  960784.313700    78431.372550   1.700000e+01
# 332835             646.605366    6138.719526       23.640768   4.441480e+04
# 801054               0.000000       2.341117        0.780372   1.708586e+06
#
#         Flow IAT Std  Flow IAT Max  Flow IAT Min  Fwd IAT Total  Fwd IAT Mean  \
# 238551  0.000000e+00          17.0          17.0              0  0.000000e+00
# 688424  2.830000e+07    98200000.0           1.0       98200000  1.640000e+07
# 227367  0.000000e+00          44.0          44.0              0  0.000000e+00
# 439735  2.886751e+00          27.0          22.0             49  4.900000e+01
# 230560  0.000000e+00          20.0          20.0              0  0.000000e+00
# 215897  0.000000e+00          21.0          21.0              0  0.000000e+00
# 826781  2.753743e+06    10000000.0           0.0      118000000  1.879805e+06
# 482204  2.260531e+01          43.0           2.0             51  2.550000e+01
# 332835  1.082368e+05      482995.0          15.0         888296  7.402467e+04
# 801054  2.946099e+06     5110437.0          44.0        5125758  2.562879e+06
#
#          Fwd IAT Std  Fwd IAT Max  Fwd IAT Min  Bwd IAT Total  Bwd IAT Mean  \
# 238551  0.000000e+00            0          0.0              0  0.000000e+00
# 688424  4.010000e+07     98200000          1.0         148483  2.969660e+04
# 227367  0.000000e+00            0          0.0              0  0.000000e+00
# 439735  0.000000e+00           49         49.0             49  4.900000e+01
# 230560  0.000000e+00            0          0.0              0  0.000000e+00
# 215897  0.000000e+00            0          0.0              0  0.000000e+00
# 826781  3.840057e+06     10000000          1.0      113000000  1.552896e+06
# 482204  3.323402e+01           49          2.0              0  0.000000e+00
# 332835  1.335989e+05       482995         15.0         358940  5.127714e+04
# 801054  3.602791e+06      5110437      15321.0              0  0.000000e+00
#
#          Bwd IAT Std  Bwd IAT Max  Bwd IAT Min  Fwd PSH Flags  \
# 238551  0.000000e+00            0            0              0
# 688424  5.971666e+04       136117           46              0
# 227367  0.000000e+00            0            0              0
# 439735  0.000000e+00           49           49              0
# 230560  0.000000e+00            0            0              0
# 215897  0.000000e+00            0            0              0
# 826781  3.604728e+06     10000000           48              0
# 482204  0.000000e+00            0            0              0
# 332835  6.886599e+04       171941          165              0
# 801054  0.000000e+00            0            0              0
#
#         Fwd Header Length  Bwd Header Length  Fwd Packets/s  Bwd Packets/s  \
# 238551                 40                 20   58823.529410   58823.529410
# 688424                220                200       0.071183       0.061014
# 227367                 24                 20   22727.272730   22727.272730
# 439735                 48                 40   28169.014080   28169.014080
# 230560                 24                 20   50000.000000   50000.000000
# 215897                 24                 20   47619.047620   47619.047620
# 826781               2056               2376       0.540414       0.624854
# 482204                 60                 20   58823.529410   19607.843140
# 332835                424                264      14.634761       9.006007
# 801054                 72                 32       0.585279       0.195093
#
#         Min Packet Length  Max Packet Length  Packet Length Mean  \
# 238551                  0                  6            2.000000
# 688424                  0               5792          853.785714
# 227367                  2                  6            3.333333
# 439735                  2                  6            3.600000
# 230560                  2                  6            3.333333
# 215897                  2                  6            3.333333
# 826781                  0               4344          817.431655
# 482204                  6                 31           11.000000
# 332835                  0               1448          247.863636
# 801054                  0                  6            2.400000
#
#         Packet Length Std  Packet Length Variance  FIN Flag Count  \
# 238551           3.464102            1.200000e+01               0
# 688424        1666.640111            2.777689e+06               0
# 227367           2.309401            5.333333e+00               0
# 439735           2.190890            4.800000e+00               0
# 230560           2.309401            5.333333e+00               0
# 215897           2.309401            5.333333e+00               0
# 826781        1037.772741            1.076972e+06               0
# 482204          11.180340            1.250000e+02               0
# 332835         472.592777            2.233439e+05               0
# 801054           3.286335            1.080000e+01               0
#
#         SYN Flag Count  RST Flag Count  PSH Flag Count  ACK Flag Count  \
# 238551               0               0               1               0
# 688424               0               0               0               1
# 227367               0               0               1               0
# 439735               0               0               1               0
# 230560               0               0               1               0
# 215897               0               0               1               0
# 826781               0               0               1               0
# 482204               0               0               0               1
# 332835               0               0               1               0
# 801054               0               0               1               0
#
#         URG Flag Count  ECE Flag Count  Down/Up Ratio  Average Packet Size  \
# 238551               0               0              1             3.000000
# 688424               0               0              0           919.461538
# 227367               0               0              1             5.000000
# 439735               0               0              1             4.500000
# 230560               0               0              1             5.000000
# 215897               0               0              1             5.000000
# 826781               0               0              1           823.355073
# 482204               0               0              0            13.750000
# 332835               0               0              0           259.666667
# 801054               0               0              0             3.000000
#
#         Avg Fwd Segment Size  Avg Bwd Segment Size  Subflow Fwd Packets  \
# 238551              0.000000              6.000000                    1
# 688424             51.142857           1932.500000                    7
# 227367              2.000000              6.000000                    1
# 439735              2.000000              6.000000                    2
# 230560              2.000000              6.000000                    1
# 215897              2.000000              6.000000                    1
# 826781             25.093750           1513.743243                   64
# 482204             14.333333              6.000000                    3
# 332835             40.846154            615.250000                   13
# 801054              4.000000              0.000000                    3
#
#         Subflow Fwd Bytes  Subflow Bwd Packets  Subflow Bwd Bytes  \
# 238551                  0                    1                  6
# 688424                358                    6              11595
# 227367                  2                    1                  6
# 439735                  4                    2                 12
# 230560                  2                    1                  6
# 215897                  2                    1                  6
# 826781               1606                   74             112017
# 482204                 43                    1                  6
# 332835                531                    8               4922
# 801054                 12                    1                  0
#
#         Init_Win_bytes_forward  Init_Win_bytes_backward  act_data_pkt_fwd  \
# 238551                 29200.0                      0.0                 0
# 688424                   251.0                    235.0                 2
# 227367                  1024.0                      0.0                 0
# 439735                  1024.0                      0.0                 1
# 230560                  1024.0                      0.0                 0
# 215897                  1024.0                      0.0                 0
# 826781                 29200.0                   1073.0                 6
# 482204                   946.0                      0.0                 2
# 332835                 29200.0                    972.0                 4
# 801054                  8192.0                  29200.0                 2
#
#         min_seg_size_forward  Active Mean   Active Std  Active Max  \
# 238551                  40.0          0.0       0.0000           0
# 688424                  20.0          8.0       0.0000           8
# 227367                  24.0          0.0       0.0000           0
# 439735                  24.0          0.0       0.0000           0
# 230560                  24.0          0.0       0.0000           0
# 215897                  24.0          0.0       0.0000           0
# 826781                  32.0     275820.5  902769.6378     3142499
# 482204                  20.0          0.0       0.0000           0
# 332835                  32.0          0.0       0.0000           0
# 801054                  20.0          0.0       0.0000           0
#
#         Active Min     Idle Mean     Idle Std  Idle Max  Idle Min  \
# 238551           0  0.000000e+00        0.000         0         0
# 688424           8  9.820000e+07        0.000  98200000  98200000
# 227367           0  0.000000e+00        0.000         0         0
# 439735           0  0.000000e+00        0.000         0         0
# 230560           0  0.000000e+00        0.000         0         0
# 215897           0  0.000000e+00        0.000         0         0
# 826781       15014  9.593154e+06  1430429.206  10000000   5051057
# 482204           0  0.000000e+00        0.000         0         0
# 332835           0  0.000000e+00        0.000         0         0
# 801054           0  0.000000e+00        0.000         0         0
#
#        Label_grouped
# 238551      PortScan
# 688424      DoS/DDoS
# 227367      PortScan
# 439735        BENIGN
# 230560      PortScan
# 215897      PortScan
# 826781        BENIGN
# 482204        BENIGN
# 332835        BENIGN
# 801054        BENIGN

# %%
df.shape
# Out:
# (894827, 68)

# %%
# label_enc = {"BENIGN":0, "DoS/DDoS":1, "PortScan":2, "Infiltration":3}
# combined_df["y"] = combined_df["Label_grouped"].map(label_enc)
from sklearn.preprocessing import LabelEncoder

# Separate X and y
X = df.drop(columns=['Label_grouped'])
y = df['Label_grouped']

# Encode label if not already
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# Check mapping (e.g., {'BENIGN': 0, 'DDoS': 1})
label_mapping = dict(zip(label_encoder.classes_, label_encoder.transform(label_encoder.classes_)))
print("Label Mapping:", label_mapping)
# Out:
# Label Mapping: {'BENIGN': 0, 'DoS/DDoS': 1, 'Other': 2, 'PortScan': 3, 'Web Attack': 4}

# %%
cols_to_drop = [
    'ECE Flag Count',          # Extremely rare
    'URG Flag Count',          # Rare in most samples
    'Bwd Packet Length Min',   # Highly skewed & redundant
    'Bwd Packet Length Max',   # High correlation with other packet lengths
    'Bwd Packets/s',           # Consider if correlated with Flow Packets/s
    'Subflow Bwd Packets',     # Possibly redundant
    'Subflow Bwd Bytes',       # Ditto
    # Add any columns with >99.9% zeros or duplicates
]

X_reduced = X.drop(columns=cols_to_drop)
X_reduced.reset_index(drop=True, inplace=True)
print("New shape:", X_reduced.shape)
# Out:
# New shape: (894827, 60)

# %%
#plot multiple plot in one functions
def All_plot(X):
    import numpy as np
    import matplotlib.pyplot as plt
    import seaborn as sns
    from scipy import stats
    col = X.columns
    for column in col:
        if np.issubdtype(X[column].dtype, np.number):  # Check if the column is numeric
            # fig, axes = plt.subplots(1, 3, figsize=(21, 6))  # 3 plots in a row

            skewness = X[column].skew()

            # Determine skewness type
            if skewness > 0:
                skew_type = "Positive Skewness"
            elif skewness < 0:
                skew_type = "Negative Skewness"
            else:
                skew_type = "Approximately Symmetrical"

            print(f"{column}: Skewness = {skewness:.2f} ({skew_type})")

            # # KDE plot
            # sns.kdeplot(X[column].dropna(), fill=True, color='blue', alpha=0.5, ax=axes[0])
            # axes[0].set_title(f"KDE Plot for {column}\n(Skewness: {skewness:.2f}) ({skew_type})", fontsize=12)
            # axes[0].set_xlabel(column)
            # axes[0].set_ylabel('Density')
            # axes[0].grid(alpha=0.3)

            # # Q-Q plot
            # stats.probplot(X[column].dropna(), dist="norm", plot=axes[1])
            # axes[1].set_title(f"Q-Q Plot for {column}", fontsize=12)

            # # Boxplot
            # sns.boxplot(x=X[column], ax=axes[2])
            # axes[2].set_title(f"Boxplot for {column}", fontsize=12)
            # axes[2].set_xlabel(column)

            # plt.tight_layout()
            # plt.show()

# %%
All_plot(X_reduced)
# Out:
# Destination Port: Skewness = 1.82 (Positive Skewness)
# Flow Duration: Skewness = 0.95 (Positive Skewness)
# Total Fwd Packets: Skewness = 259.45 (Positive Skewness)
# Total Backward Packets: Skewness = 261.60 (Positive Skewness)
# Total Length of Fwd Packets: Skewness = 619.05 (Positive Skewness)
# Total Length of Bwd Packets: Skewness = 259.12 (Positive Skewness)
# Fwd Packet Length Max: Skewness = 6.36 (Positive Skewness)
# Fwd Packet Length Min: Skewness = 15.72 (Positive Skewness)
# Fwd Packet Length Mean: Skewness = 5.66 (Positive Skewness)
# Fwd Packet Length Std: Skewness = 6.90 (Positive Skewness)
# Bwd Packet Length Mean: Skewness = 0.97 (Positive Skewness)
# Bwd Packet Length Std: Skewness = 1.62 (Positive Skewness)
# Flow Bytes/s: Skewness = 113.27 (Positive Skewness)
# Flow Packets/s: Skewness = 14.15 (Positive Skewness)
# Flow IAT Mean: Skewness = 3.50 (Positive Skewness)
# Flow IAT Std: Skewness = 1.61 (Positive Skewness)
# Flow IAT Max: Skewness = 1.39 (Positive Skewness)
# Flow IAT Min: Skewness = 165.89 (Positive Skewness)
# Fwd IAT Total: Skewness = 0.96 (Positive Skewness)
# Fwd IAT Mean: Skewness = 4.58 (Positive Skewness)
# Fwd IAT Std: Skewness = 1.55 (Positive Skewness)
# Fwd IAT Max: Skewness = 1.39 (Positive Skewness)
# Fwd IAT Min: Skewness = 22.97 (Positive Skewness)
# Bwd IAT Total: Skewness = 1.86 (Positive Skewness)
# Bwd IAT Mean: Skewness = 7.29 (Positive Skewness)
# Bwd IAT Std: Skewness = 3.38 (Positive Skewness)
# Bwd IAT Max: Skewness = 2.95 (Positive Skewness)
# Bwd IAT Min: Skewness = 16.02 (Positive Skewness)
# Fwd PSH Flags: Skewness = 4.54 (Positive Skewness)
# Fwd Header Length: Skewness = 259.57 (Positive Skewness)
# Bwd Header Length: Skewness = 261.19 (Positive Skewness)
# Fwd Packets/s: Skewness = 14.50 (Positive Skewness)
# Min Packet Length: Skewness = 2.08 (Positive Skewness)
# Max Packet Length: Skewness = 1.20 (Positive Skewness)
# Packet Length Mean: Skewness = 0.90 (Positive Skewness)
# Packet Length Std: Skewness = 1.24 (Positive Skewness)
# Packet Length Variance: Skewness = 2.86 (Positive Skewness)
# FIN Flag Count: Skewness = 3.24 (Positive Skewness)
# SYN Flag Count: Skewness = 4.54 (Positive Skewness)
# RST Flag Count: Skewness = 46.46 (Positive Skewness)
# PSH Flag Count: Skewness = -0.34 (Negative Skewness)
# ACK Flag Count: Skewness = 0.64 (Positive Skewness)
# Down/Up Ratio: Skewness = 12.94 (Positive Skewness)
# Average Packet Size: Skewness = 0.97 (Positive Skewness)
# Avg Fwd Segment Size: Skewness = 5.66 (Positive Skewness)
# Avg Bwd Segment Size: Skewness = 0.97 (Positive Skewness)
# Subflow Fwd Packets: Skewness = 259.45 (Positive Skewness)
# Subflow Fwd Bytes: Skewness = 618.07 (Positive Skewness)
# Init_Win_bytes_forward: Skewness = 1.54 (Positive Skewness)
# Init_Win_bytes_backward: Skewness = 4.75 (Positive Skewness)
# act_data_pkt_fwd: Skewness = 259.48 (Positive Skewness)
# min_seg_size_forward: Skewness = 0.67 (Positive Skewness)
# Active Mean: Skewness = 31.65 (Positive Skewness)
# Active Std: Skewness = 36.56 (Positive Skewness)
# Active Max: Skewness = 21.37 (Positive Skewness)
# Active Min: Skewness = 39.54 (Positive Skewness)
# Idle Mean: Skewness = 1.49 (Positive Skewness)
# Idle Std: Skewness = 6.35 (Positive Skewness)
# Idle Max: Skewness = 1.40 (Positive Skewness)
# Idle Min: Skewness = 1.58 (Positive Skewness)

# %%
columns_to_transform = [
    'Destination Port', 'Total Fwd Packets', 'Total Backward Packets',
    'Total Length of Fwd Packets', 'Total Length of Bwd Packets',
    'Fwd Packet Length Max', 'Fwd Packet Length Min',
    'Fwd Packet Length Mean', 'Fwd Packet Length Std',
    'Bwd Packet Length Std', 'Flow Bytes/s', 'Flow Packets/s',
    'Flow IAT Mean', 'Flow IAT Std', 'Flow IAT Max',
    'Flow IAT Min', 'Fwd IAT Mean', 'Fwd IAT Std',
    'Fwd IAT Min', 'Bwd IAT Mean', 'Bwd IAT Std',
    'Bwd IAT Max', 'Bwd IAT Min', 'Fwd PSH Flags',
    'Fwd Header Length', 'Bwd Header Length',
    'Fwd Packets/s', 'Min Packet Length', 'Packet Length Variance',
    'FIN Flag Count', 'SYN Flag Count', 'RST Flag Count',
    'URG Flag Count', 'ECE Flag Count', 'Down/Up Ratio',
    'Avg Fwd Segment Size', 'Subflow Fwd Packets',
    'Subflow Fwd Bytes', 'Init_Win_bytes_forward',
    'Init_Win_bytes_backward', 'act_data_pkt_fwd',
    'Active Mean', 'Active Std', 'Active Max', 'Active Min',
    'Idle Std'
]

# %%
chunk_size = 50000
n = X_reduced.shape[0]

transformed_chunks = []
lambdas_list = []

for start in range(0, n, chunk_size):
    end = min(start + chunk_size, n)
    X_chunk = X_reduced.iloc[start:end].copy()
    # Note: ensure X_chunk does *not* include target columns like 'y'
    
    transformed_X_chunk, lambdas = Advance_column_transformer(
        X_chunk,
        columns=columns_to_transform,
        method='yeo-johnson',
        standardize=True
    )
    
    transformed_chunks.append(transformed_X_chunk)
    lambdas_list.append(lambdas)

# Reconstruct the full transformed DataFrame:
transformed_X = pd.concat(transformed_chunks, ignore_index=True)

# For simplicity, assume each chunk uses same lambdas:
lambdas_X = lambdas_list[0]

# %%
All_plot(transformed_X)
# Out:
# Destination Port: Skewness = -0.35 (Negative Skewness)
# Total Fwd Packets: Skewness = 0.24 (Positive Skewness)
# Total Backward Packets: Skewness = 0.26 (Positive Skewness)
# Total Length of Fwd Packets: Skewness = 0.65 (Positive Skewness)
# Total Length of Bwd Packets: Skewness = 0.31 (Positive Skewness)
# Fwd Packet Length Max: Skewness = 0.68 (Positive Skewness)
# Fwd Packet Length Min: Skewness = 2.45 (Positive Skewness)
# Fwd Packet Length Mean: Skewness = 0.56 (Positive Skewness)
# Fwd Packet Length Std: Skewness = 1.52 (Positive Skewness)
# Bwd Packet Length Std: Skewness = 1.41 (Positive Skewness)
# Flow Bytes/s: Skewness = 4.12 (Positive Skewness)
# Flow Packets/s: Skewness = -2.68 (Negative Skewness)
# Flow IAT Mean: Skewness = -1.05 (Negative Skewness)
# Flow IAT Std: Skewness = 0.58 (Positive Skewness)
# Flow IAT Max: Skewness = -1.15 (Negative Skewness)
# Flow IAT Min: Skewness = -7.73 (Negative Skewness)
# Fwd IAT Mean: Skewness = 0.75 (Positive Skewness)
# Fwd IAT Std: Skewness = 0.80 (Positive Skewness)
# Fwd IAT Min: Skewness = 1.10 (Positive Skewness)
# Bwd IAT Mean: Skewness = 1.27 (Positive Skewness)
# Bwd IAT Std: Skewness = 1.56 (Positive Skewness)
# Bwd IAT Max: Skewness = 1.26 (Positive Skewness)
# Bwd IAT Min: Skewness = 1.48 (Positive Skewness)
# Fwd PSH Flags: Skewness = 9.57 (Positive Skewness)
# Fwd Header Length: Skewness = 0.05 (Positive Skewness)
# Bwd Header Length: Skewness = 0.31 (Positive Skewness)
# Fwd Packets/s: Skewness = 0.71 (Positive Skewness)
# Min Packet Length: Skewness = 5.80 (Positive Skewness)
# Packet Length Variance: Skewness = -0.41 (Negative Skewness)
# FIN Flag Count: Skewness = 11.15 (Positive Skewness)
# SYN Flag Count: Skewness = 9.57 (Positive Skewness)
# RST Flag Count: Skewness = 98.97 (Positive Skewness)
# Down/Up Ratio: Skewness = 2.12 (Positive Skewness)
# Avg Fwd Segment Size: Skewness = 0.56 (Positive Skewness)
# Subflow Fwd Packets: Skewness = 0.24 (Positive Skewness)
# Subflow Fwd Bytes: Skewness = 0.65 (Positive Skewness)
# Init_Win_bytes_forward: Skewness = 0.91 (Positive Skewness)
# Init_Win_bytes_backward: Skewness = 0.99 (Positive Skewness)
# act_data_pkt_fwd: Skewness = 1.36 (Positive Skewness)
# Active Mean: Skewness = 1.99 (Positive Skewness)
# Active Std: Skewness = 5.55 (Positive Skewness)
# Active Max: Skewness = 2.00 (Positive Skewness)
# Active Min: Skewness = 1.98 (Positive Skewness)
# Idle Std: Skewness = 4.18 (Positive Skewness)
# Flow Duration: Skewness = 0.95 (Positive Skewness)
# Bwd Packet Length Mean: Skewness = 0.97 (Positive Skewness)
# Fwd IAT Total: Skewness = 0.96 (Positive Skewness)
# Fwd IAT Max: Skewness = 1.39 (Positive Skewness)
# Bwd IAT Total: Skewness = 1.86 (Positive Skewness)
# Max Packet Length: Skewness = 1.20 (Positive Skewness)
# Packet Length Mean: Skewness = 0.90 (Positive Skewness)
# Packet Length Std: Skewness = 1.24 (Positive Skewness)
# PSH Flag Count: Skewness = -0.34 (Negative Skewness)
# ACK Flag Count: Skewness = 0.64 (Positive Skewness)
# Average Packet Size: Skewness = 0.97 (Positive Skewness)
# Avg Bwd Segment Size: Skewness = 0.97 (Positive Skewness)
# min_seg_size_forward: Skewness = 0.67 (Positive Skewness)
# Idle Mean: Skewness = 1.49 (Positive Skewness)
# Idle Max: Skewness = 1.40 (Positive Skewness)
# Idle Min: Skewness = 1.58 (Positive Skewness)

# %%
# import numpy as np
# import pandas as pd

# def cap_outliers_iqr_chunkwise(df, chunk_size=50000, inplace=False):
#     """
#     Applies IQR-based outlier capping in chunks to reduce memory usage.
#     Returns a new capped DataFrame by default.
#     """
#     df_out = [] if not inplace else None

#     n = df.shape[0]
#     for start in range(0, n, chunk_size):
#         end = min(start + chunk_size, n)
#         chunk = df.iloc[start:end].copy()

#         # Apply capping per-column
#         for col in chunk.select_dtypes(include=[np.number]).columns:
#             Q1 = chunk[col].quantile(0.25)
#             Q3 = chunk[col].quantile(0.75)
#             IQR = Q3 - Q1

#             if IQR == 0 or pd.isna(IQR):
#                 continue  # skip constant or empty columns

#             low, high = Q1 - 1.5 * IQR, Q3 + 1.5 * IQR
#             chunk[col] = chunk[col].clip(lower=low, upper=high)

#         if inplace:
#             df.iloc[start:end] = chunk.values
#         else:
#             df_out.append(chunk)

#     if not inplace:
#         return pd.concat(df_out, ignore_index=True)

# X_fin_capped = cap_outliers_iqr_chunkwise(transformed_X, chunk_size=50000, inplace=False)
